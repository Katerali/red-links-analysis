# %% [markdown]
# ## Retrieve red links considering oldest reference pages (among main pages and redirections)

# %%
import mwparserfromhell
import numpy as np
import pandas as pd
import re
from mw.xml_dump import Iterator
from mw import Timestamp

# %%
from collections import defaultdict

# %%
# to make interactive plotting possible
# %matplotlib inline

# for auto-reloading external modules
# %load_ext autoreload
# %autoreload 2

# make plots a bit nicer
import matplotlib.pyplot as plt
plt.matplotlib.rcParams.update({'font.size': 18, 'font.family': 'serif'})

# %%
from datetime import date, time, datetime

# %%
import matplotlib.patches as mpatches

# %% [markdown]
# ## helpers

# %%
def multiple_replace(text):
    
    adict = {'[[': '', ']]': '', ' ': '_'}
    
  # Create a regular expression from all of the dictionary keys
    regex = re.compile("|".join(map(re.escape, adict.keys(  ))))

  # For each match, look up the corresponding value in the dictionary
    sub_text = regex.sub(lambda match: adict[match.group(0)], text)

    first_title = re.split("\|", sub_text)
    
    return first_title[0]

# %%
def aux_fun(x):
    try:
        return Timestamp(np.int64(x))
    except:
        print(x)
        return None

# %%
def link_status(rvtime, page_creation_time):
    if pd.isnull(page_creation_time) or page_creation_time > rvtime:
        return 'red link'
    if page_creation_time <= rvtime:
        return 'blue link'

# %% [markdown]
# ### create a table of all pages and redirection with min time of page creation

# %%
# !RUN ONCE

# load a table with page creation time for ukwiki
page_creation_df = pd.read_csv('../data/'+'timestamp-for-first-revision-of-all-articles-in-ukwiki.tsv', sep = '\t',)

# load a table with redirects in ukwiki
redirects_df = pd.read_csv('../data/'+'ukredirect.tsv', sep = '\t',)

redirects_df.columns = ['rd_id', 'ref_title', 'rd_interwiki']

redirects_df = redirects_df[['rd_id', 'ref_title']]

pagestamp_with_redirects_df = page_creation_df.merge(redirects_df, left_on='page_id', right_on='rd_id', how='outer')

pagestamp_with_redirects_df.columns = ['page_creation_timestamp', 'ref_title', 'page_id', 'rd_id', 'main_page_title']

pagestamp_with_redirects_df = pagestamp_with_redirects_df[pagestamp_with_redirects_df['page_creation_timestamp'].notnull()]

pagetime_redirects_df = pagestamp_with_redirects_df[pagestamp_with_redirects_df['rd_id'].notnull()]

pagetime_main_df = pagestamp_with_redirects_df[pagestamp_with_redirects_df['rd_id'].isnull()]

pagetime_main_df['main_page_title'] = pagetime_main_df[['main_page_title']].apply(lambda x: pagetime_main_df['ref_title'], axis=0)

final_pagetime_df = pd.concat([pagetime_redirects_df, pagetime_main_df])

final_pagetime_df.page_creation_timestamp = final_pagetime_df.page_creation_timestamp.apply(lambda x: Timestamp(np.int64(x)))

min_pagetime_df = final_pagetime_df.groupby(['main_page_title'])['page_creation_timestamp'].min()

min_pagetime_df = min_pagetime_df.to_frame()

min_pagetime_df.reset_index(level=0, inplace=True)

final_pagetime_df = final_pagetime_df.merge(min_pagetime_df, on='main_page_title', how='left')

del final_pagetime_df['page_creation_timestamp_x']

final_pagetime_df.columns = ['ref_title', 'page_id', 'rd_id', 'main_page_title', 'min_pagecreation_timestamp']

final_pagetime_df.to_csv('../working_files/'+'final_pagetime_df.tsv', index=False, sep = '\t')

# %% [markdown]
# ## get red links

# %%
page_creation_df = pd.read_csv('../working_files/'+'final_pagetime_df.tsv', sep = '\t')

# %%
page_creation_df.head()
# Out:
#                       ref_title    page_id      rd_id         main_page_title  \
# 0                             !   829961.0   829961.0             Знак_оклику
# 1                            !!  2062457.0  2062457.0               Факторіал
# 2  !!!Fuck_You!!!_and_Then_Some  2591631.0  2591631.0  Fuck_You_and_Then_Some
# 3                  !Action_Pact  1767358.0  1767358.0           !Action_Pact!
# 4                     !T.O.O.H.  1767359.0  1767359.0              !T.O.O.H.!
#
#    min_pagecreation_timestamp
# 0                2.008033e+13
# 1                2.004041e+13
# 2                2.015062e+13
# 3                2.010111e+13
# 4                2.009033e+13

# %% [markdown]
# ### Check for chosen pages

# %%
# !RUN ONCE

noise_pages = ('Головна сторінка', 'Обговорення:', 'Обговорення користувача:', 'Обговорення Вікіпедії:', 'Категорія:', 'Шаблон:', 'Вікіпедія:',
               'Файл:','Користувач:', 'Категорія:Списки:', 'Портал:', 'Довідка:', ':Категорія')

# Construct dump file iterator
dump = Iterator.from_file(open("/media/andrii/earth/Katia/CS/!redlinks_project/red-links-v2.0/data/ukwiki_dumps/ukwiki-20200501-pages-meta-history1.xml-p1p17370"))

# Iterate through i pages
stopwords = ['[[Категорія:', '[[Файл:']
revs_links_time = []

i = 1000
for page in dump:
    if i == 0:
        break
    elif page.title.startswith(noise_pages):
        continue
    elif page.redirect is not None:
        continue
    else:
        print('PAGE TITLE:', page.title)
        for revision in page:
            timestamp = revision.timestamp
            revision = revision.text
            get_revision = mwparserfromhell.parse(revision)
            links = get_revision.filter_wikilinks()
            filtered = []
            for l in links:
                if not any([sw in l for sw in stopwords]):
                    revs_links_time.append((str(page.title), str(l), timestamp))
    i -= 1

# %%
# get latest revisions of pages

noise_pages = ('Головна сторінка', 'Обговорення:', 'Обговорення користувача:', 'Обговорення Вікіпедії:', 'Категорія:', 'Шаблон:', 'Вікіпедія:',
               'Файл:','Користувач:', 'Категорія:Списки:', 'Портал:', 'Довідка:', ':Категорія')

# Construct dump file iterator
dump = Iterator.from_file(open("/media/andrii/earth/Katia/CS/!redlinks_project/red-links-v2.0/data/ukwiki_dumps/ukwiki-20200501-pages-meta-history1.xml-p1p17370"))

# Iterate through i pages
stopwords = ['[[Категорія:', '[[Файл:']
revs_time = {}

i = 1000
for page in dump:
    page_revisions = []
    if i == 0:
        break
    elif page.title.startswith(noise_pages):
        continue
    elif page.redirect is not None:
        continue
    else:
        page_title = page.title
        print('PAGE TITLE:', page_title)
        for revision in page:
            timestamp = revision.timestamp
            page_revisions.append(timestamp)
    revs_time[page_title] = page_revisions
    i -= 1

latest_revisions = {}
for k, v in revs_time.items():
    latest_revisions[k] = max(v)

latest_revisions_df = pd.DataFrame.from_dict(latest_revisions, orient='index')

latest_revisions_df.columns = ['rvtimestamp']

latest_revisions_df.to_csv(('../working_files/'+'latest_revisions_df.csv'))
# Out:
# PAGE TITLE: Географія
# PAGE TITLE: Атом
# PAGE TITLE: Мільярд
# PAGE TITLE: Ядро
# PAGE TITLE: Мільйон
# PAGE TITLE: Хімія
# PAGE TITLE: Діаметр
# PAGE TITLE: Метр
# PAGE TITLE: Біологія
# PAGE TITLE: Коло
# PAGE TITLE: Довжина
# PAGE TITLE: Точка
# PAGE TITLE: Крапка
# PAGE TITLE: Речення
# PAGE TITLE: Слово
# PAGE TITLE: Мова
# PAGE TITLE: Радіус
# PAGE TITLE: Есперанто
# PAGE TITLE: 1944
# PAGE TITLE: 1854
# PAGE TITLE: 1912
# PAGE TITLE: 1929
# PAGE TITLE: 1999
# PAGE TITLE: Високович Володимир Костянтинович
# PAGE TITLE: Молостова Ірина Олександрівна
# PAGE TITLE: 1834
# PAGE TITLE: 1908
# PAGE TITLE: Антонович Володимир Боніфатійович
# PAGE TITLE: 1904
# PAGE TITLE: 1985
# PAGE TITLE: Комар Антон Пантелеймонович
# PAGE TITLE: Фізик
# PAGE TITLE: Фізика
# PAGE TITLE: Закон (право)
# PAGE TITLE: 1961
# PAGE TITLE: Довгаль Олександр Михайлович
# PAGE TITLE: 1839
# PAGE TITLE: 1884
# PAGE TITLE: Чубинський Павло Платонович
# PAGE TITLE: Гімн України
# PAGE TITLE: Рудольф Людвіг Мессбауер
# PAGE TITLE: 1979
# PAGE TITLE: Омеляновський Михайло Еразмович
# PAGE TITLE: Україна
# PAGE TITLE: Кіло-
# PAGE TITLE: 1879
# PAGE TITLE: 1969
# PAGE TITLE: Політика
# PAGE TITLE: Філософ
# PAGE TITLE: Людина розумна
# PAGE TITLE: Лебедєв Сергій Олексійович
# PAGE TITLE: Союз Радянських Соціалістичних Республік
# PAGE TITLE: Мороз Олександр Олександрович
# PAGE TITLE: 978
# PAGE TITLE: 1054
# PAGE TITLE: Ярослав Мудрий
# PAGE TITLE: 1941
# PAGE TITLE: Гео Коляда
# PAGE TITLE: 1900
# PAGE TITLE: Корсаков Сергій Сергійович
# PAGE TITLE: 1919
# PAGE TITLE: Команов Геннадій Геннадійович
# PAGE TITLE: 1943
# PAGE TITLE: 1916
# PAGE TITLE: Мидловський Ісидор Михайлович
# PAGE TITLE: Письменник
# PAGE TITLE: Поет
# PAGE TITLE: Література
# PAGE TITLE: 1880
# PAGE TITLE: Владко Володимир Миколайович
# PAGE TITLE: Інформатика
# PAGE TITLE: Математика
# PAGE TITLE: Інформація
# PAGE TITLE: Кібернетика
# PAGE TITLE: 1917
# PAGE TITLE: 1804
# PAGE TITLE: 1860
# PAGE TITLE: Маркевич Микола Андрійович
# PAGE TITLE: 1939
# PAGE TITLE: Колесник Раїса Самсонівна
# PAGE TITLE: 1914
# PAGE TITLE: Іван Багряний
# PAGE TITLE: Федькович Осип-Юрій Адальбертович
# PAGE TITLE: Франко Іван Якович
# PAGE TITLE: Глазовий Павло Прокопович
# PAGE TITLE: Загребельний Павло Архипович
# PAGE TITLE: 1994
# PAGE TITLE: 1907
# PAGE TITLE: Менделєєв Дмитро Іванович
# PAGE TITLE: Кецало Зеновій Євстахович
# PAGE TITLE: 1973
# PAGE TITLE: Мушак Юрій Федорович
# PAGE TITLE: 1829
# PAGE TITLE: 1877
# PAGE TITLE: Фізична географія
# PAGE TITLE: Технологія
# PAGE TITLE: Інтернет
# PAGE TITLE: База даних
# PAGE TITLE: Музика
# PAGE TITLE: Шевченко Тарас Григорович
# PAGE TITLE: Чернівці
# PAGE TITLE: Леся Українка
# PAGE TITLE: Наука
# PAGE TITLE: Художник
# PAGE TITLE: Бриж Теодозія Марківна
# PAGE TITLE: Список країн світу
# PAGE TITLE: Мовознавство
# PAGE TITLE: Словотвір
# PAGE TITLE: Фонетика
# PAGE TITLE: Орфоепія
# PAGE TITLE: Лексикологія
# PAGE TITLE: Омоніми
# PAGE TITLE: Синонім
# PAGE TITLE: Антонім
# PAGE TITLE: Морфологія
# PAGE TITLE: Іменник
# PAGE TITLE: Прикметник
# PAGE TITLE: Числівник
# PAGE TITLE: Дієприкметник
# PAGE TITLE: Дієприслівник
# PAGE TITLE: Міфологія
# PAGE TITLE: Коркушко Олег Васильович
# PAGE TITLE: 1889
# PAGE TITLE: 1977
# PAGE TITLE: Ревуцький Лев Миколайович
# PAGE TITLE: Фразеологія
# PAGE TITLE: Лексикографія
# PAGE TITLE: Ще не вмерла Україна
# PAGE TITLE: MySQL
# PAGE TITLE: PostgreSQL
# PAGE TITLE: Oracle
# PAGE TITLE: Microsoft SQL Server
# PAGE TITLE: Informix
# PAGE TITLE: Київ
# PAGE TITLE: Бертран Расселл
# PAGE TITLE: Граматика
# PAGE TITLE: Синтаксис
# PAGE TITLE: Пунктуація
# PAGE TITLE: Елементарна математика
# PAGE TITLE: Формули скороченого множення
# PAGE TITLE: Firebird
# PAGE TITLE: Професія
# PAGE TITLE: Список професій
# PAGE TITLE: Астрономія
# PAGE TITLE: Дієслово
# PAGE TITLE: Залежні території
# PAGE TITLE: Економічна географія
# PAGE TITLE: Ельфріде Єлінек
# PAGE TITLE: Археологія
# PAGE TITLE: Київський національний університет імені Тараса Шевченка
# PAGE TITLE: Історична вісь
# PAGE TITLE: 1933
# PAGE TITLE: 1945
# PAGE TITLE: 1913
# PAGE TITLE: 1838
# PAGE TITLE: 1878
# PAGE TITLE: 1801
# PAGE TITLE: 1802
# PAGE TITLE: 1803
# PAGE TITLE: 1805
# PAGE TITLE: 1806
# PAGE TITLE: 1807
# PAGE TITLE: 1808
# PAGE TITLE: 1809
# PAGE TITLE: 1810
# PAGE TITLE: 1811
# PAGE TITLE: 1812
# PAGE TITLE: 1813
# PAGE TITLE: 1814
# PAGE TITLE: 1815
# PAGE TITLE: 1816
# PAGE TITLE: 1817
# PAGE TITLE: 1818
# PAGE TITLE: 1819
# PAGE TITLE: 1820
# PAGE TITLE: 1821
# PAGE TITLE: 1822
# PAGE TITLE: 1823
# PAGE TITLE: 1824
# PAGE TITLE: 1825
# PAGE TITLE: 1826
# PAGE TITLE: 1827
# PAGE TITLE: 1800
# PAGE TITLE: 1828
# PAGE TITLE: 1830
# PAGE TITLE: 1831
# PAGE TITLE: 1832
# PAGE TITLE: 1833
# PAGE TITLE: 1835
# PAGE TITLE: 1836
# PAGE TITLE: 1837
# PAGE TITLE: 1840
# PAGE TITLE: 1841
# PAGE TITLE: 1842
# PAGE TITLE: 1843
# PAGE TITLE: 1844
# PAGE TITLE: 1845
# PAGE TITLE: 1846
# PAGE TITLE: 1847
# PAGE TITLE: 1848
# PAGE TITLE: 1849
# PAGE TITLE: 1850
# PAGE TITLE: 1851
# PAGE TITLE: 1852
# PAGE TITLE: 1853
# PAGE TITLE: 1855
# PAGE TITLE: 1856
# PAGE TITLE: 1857
# PAGE TITLE: 1858
# PAGE TITLE: 1859
# PAGE TITLE: 1861
# PAGE TITLE: 1862
# PAGE TITLE: 1863
# PAGE TITLE: 1864
# PAGE TITLE: 1865
# PAGE TITLE: 1866
# PAGE TITLE: 1867
# PAGE TITLE: 1868
# PAGE TITLE: 1869
# PAGE TITLE: 1870
# PAGE TITLE: 1871
# PAGE TITLE: 1872
# PAGE TITLE: 1873
# PAGE TITLE: 1874
# PAGE TITLE: 1875
# PAGE TITLE: 1876
# PAGE TITLE: 1881
# PAGE TITLE: 1882
# PAGE TITLE: 1883
# PAGE TITLE: 1885
# PAGE TITLE: 1886
# PAGE TITLE: 1887
# PAGE TITLE: 1888
# PAGE TITLE: 1890
# PAGE TITLE: 1891
# PAGE TITLE: 1892
# PAGE TITLE: 1893
# PAGE TITLE: 1894
# PAGE TITLE: 1895
# PAGE TITLE: 1896
# PAGE TITLE: 1897
# PAGE TITLE: 1898
# PAGE TITLE: 1899
# PAGE TITLE: 1901
# PAGE TITLE: 1902
# PAGE TITLE: 1903
# PAGE TITLE: 1905
# PAGE TITLE: 1906
# PAGE TITLE: 1909
# PAGE TITLE: 1910
# PAGE TITLE: 1911
# PAGE TITLE: 1915
# PAGE TITLE: 1918
# PAGE TITLE: 1920
# PAGE TITLE: 1921
# PAGE TITLE: 1922
# PAGE TITLE: 1923
# PAGE TITLE: 1924
# PAGE TITLE: 1925
# PAGE TITLE: 1926
# PAGE TITLE: 1927
# PAGE TITLE: 1928
# PAGE TITLE: 1930
# PAGE TITLE: 1931
# PAGE TITLE: 1932
# PAGE TITLE: 1934
# PAGE TITLE: 1935
# PAGE TITLE: 1936
# PAGE TITLE: 1937
# PAGE TITLE: 1938
# PAGE TITLE: 1940
# PAGE TITLE: 1942
# PAGE TITLE: 1946
# PAGE TITLE: 1947
# PAGE TITLE: 1948
# PAGE TITLE: 1949
# PAGE TITLE: 1950
# PAGE TITLE: 1951
# PAGE TITLE: 1952
# PAGE TITLE: 1953
# PAGE TITLE: 1954
# PAGE TITLE: 1955
# PAGE TITLE: 1956
# PAGE TITLE: 1957
# PAGE TITLE: 1958
# PAGE TITLE: 1959
# PAGE TITLE: 1960
# PAGE TITLE: 1962
# PAGE TITLE: 1963
# PAGE TITLE: 1964
# PAGE TITLE: 1965
# PAGE TITLE: 1966
# PAGE TITLE: 1967
# PAGE TITLE: 1968
# PAGE TITLE: 1970
# PAGE TITLE: 1971
# PAGE TITLE: 1972
# PAGE TITLE: 1974
# PAGE TITLE: 1975
# PAGE TITLE: 1976
# PAGE TITLE: 1978
# PAGE TITLE: 1980
# PAGE TITLE: 1981
# PAGE TITLE: 1982
# PAGE TITLE: 1983
# PAGE TITLE: 1984
# PAGE TITLE: 1986
# PAGE TITLE: 1987
# PAGE TITLE: 1988
# PAGE TITLE: 1989
# PAGE TITLE: 1990
# PAGE TITLE: 1991
# PAGE TITLE: 1992
# PAGE TITLE: 1993
# PAGE TITLE: 1995
# PAGE TITLE: 1996
# PAGE TITLE: 1997
# PAGE TITLE: 1998
# PAGE TITLE: 2000
# PAGE TITLE: 2001
# PAGE TITLE: 2002
# PAGE TITLE: 2003
# PAGE TITLE: 100
# PAGE TITLE: 101
# PAGE TITLE: 102
# PAGE TITLE: 103
# PAGE TITLE: 104
# PAGE TITLE: 105
# PAGE TITLE: 106
# PAGE TITLE: 107
# PAGE TITLE: 108
# PAGE TITLE: 109
# PAGE TITLE: 110
# PAGE TITLE: 1798
# PAGE TITLE: 1797
# PAGE TITLE: 1796
# PAGE TITLE: 1795
# PAGE TITLE: 1794
# PAGE TITLE: 1793
# PAGE TITLE: 1792
# PAGE TITLE: 1791
# PAGE TITLE: 1790
# PAGE TITLE: 1789
# PAGE TITLE: 1788
# PAGE TITLE: 1787
# PAGE TITLE: 1786
# PAGE TITLE: 1785
# PAGE TITLE: 1784
# PAGE TITLE: 1783
# PAGE TITLE: 1782
# PAGE TITLE: 1781
# PAGE TITLE: 1780
# PAGE TITLE: 1779
# PAGE TITLE: Блог
# PAGE TITLE: Соціологія
# PAGE TITLE: Еміль Дюркгайм
# PAGE TITLE: Програмування
# PAGE TITLE: Список мов програмування
# PAGE TITLE: Java
# PAGE TITLE: XX століття
# PAGE TITLE: XIX століття
# PAGE TITLE: XXI століття
# PAGE TITLE: XVIII століття
# PAGE TITLE: Анатомія
# PAGE TITLE: Локальна мережа
# PAGE TITLE: 9 березня
# PAGE TITLE: Юрій Клен
# PAGE TITLE: Руданський Степан Васильович
# PAGE TITLE: Микола Хвильовий
# PAGE TITLE: 2 жовтня
# PAGE TITLE: 25 серпня
# PAGE TITLE: Росія
# PAGE TITLE: Польща
# PAGE TITLE: Молдова
# PAGE TITLE: Білорусь
# PAGE TITLE: Румунія
# PAGE TITLE: Угорщина
# PAGE TITLE: Словаччина
# PAGE TITLE: Чехія
# PAGE TITLE: Болгарія
# PAGE TITLE: Італія
# PAGE TITLE: Греція
# PAGE TITLE: Німеччина
# PAGE TITLE: Життя
# PAGE TITLE: Perl
# PAGE TITLE: Ada
# PAGE TITLE: C (мова програмування)
# PAGE TITLE: AWK
# PAGE TITLE: Дихальна система
# PAGE TITLE: Порожнина носа
# PAGE TITLE: Глотка
# PAGE TITLE: Гортань
# PAGE TITLE: Трахея
# PAGE TITLE: Надгортанник
# PAGE TITLE: Linux
# PAGE TITLE: Бронхи
# PAGE TITLE: Альвеола (легені)
# PAGE TITLE: Легені
# PAGE TITLE: Бронхолегеневий сегмент
# PAGE TITLE: Плевра
# PAGE TITLE: Середостіння
# PAGE TITLE: C Sharp
# PAGE TITLE: Korn-shell
# PAGE TITLE: Римська система числення
# PAGE TITLE: Фізичні константи
# PAGE TITLE: Періодична система хімічних елементів
# PAGE TITLE: Освіта
# PAGE TITLE: Український вільний університет
# PAGE TITLE: 1799
# PAGE TITLE: 1600
# PAGE TITLE: 1601
# PAGE TITLE: 1602
# PAGE TITLE: 1603
# PAGE TITLE: 1604
# PAGE TITLE: 1605
# PAGE TITLE: 1606
# PAGE TITLE: 1607
# PAGE TITLE: 1608
# PAGE TITLE: 1609
# PAGE TITLE: 1610
# PAGE TITLE: 1611
# PAGE TITLE: 1612
# PAGE TITLE: 1613
# PAGE TITLE: 1614
# PAGE TITLE: 1615
# PAGE TITLE: 1616
# PAGE TITLE: 1617
# PAGE TITLE: 1618
# PAGE TITLE: 1619
# PAGE TITLE: 1620
# PAGE TITLE: 1621
# PAGE TITLE: 1622
# PAGE TITLE: 1623
# PAGE TITLE: 1624
# PAGE TITLE: 1625
# PAGE TITLE: 1626
# PAGE TITLE: 1627
# PAGE TITLE: 1628
# PAGE TITLE: 1629
# PAGE TITLE: 1630
# PAGE TITLE: 1631
# PAGE TITLE: 1632
# PAGE TITLE: 1633
# PAGE TITLE: 1634
# PAGE TITLE: 1635
# PAGE TITLE: 1636
# PAGE TITLE: 1637
# PAGE TITLE: 1638
# PAGE TITLE: 1639
# PAGE TITLE: 1640
# PAGE TITLE: 1641
# PAGE TITLE: 1642
# PAGE TITLE: 1643
# PAGE TITLE: 1644
# PAGE TITLE: 1645
# PAGE TITLE: 1646
# PAGE TITLE: 1647
# PAGE TITLE: 1648
# PAGE TITLE: 1649
# PAGE TITLE: 1650
# PAGE TITLE: 1651
# PAGE TITLE: 1652
# PAGE TITLE: 1653
# PAGE TITLE: 1654
# PAGE TITLE: 1655
# PAGE TITLE: 1656
# PAGE TITLE: 1657
# PAGE TITLE: 1658
# PAGE TITLE: 1659
# PAGE TITLE: 1660
# PAGE TITLE: 1661
# PAGE TITLE: 1662
# PAGE TITLE: 1663
# PAGE TITLE: 1664
# PAGE TITLE: 1665
# PAGE TITLE: 1666
# PAGE TITLE: 1667
# PAGE TITLE: 1668
# PAGE TITLE: 1669
# PAGE TITLE: 1670
# PAGE TITLE: 1671
# PAGE TITLE: 1672
# PAGE TITLE: 1673
# PAGE TITLE: 1674
# PAGE TITLE: 1675
# PAGE TITLE: 1676
# PAGE TITLE: 1677
# PAGE TITLE: 1678
# PAGE TITLE: 1679
# PAGE TITLE: 1680
# PAGE TITLE: 1681
# PAGE TITLE: 1682
# PAGE TITLE: 1683
# PAGE TITLE: 1684
# PAGE TITLE: 1685
# PAGE TITLE: 1686
# PAGE TITLE: 1687
# PAGE TITLE: 1688
# PAGE TITLE: 1689
# PAGE TITLE: 1690
# PAGE TITLE: 1691
# PAGE TITLE: 1692
# PAGE TITLE: 1693
# PAGE TITLE: 1694
# PAGE TITLE: 1695
# PAGE TITLE: 1696
# PAGE TITLE: 1697
# PAGE TITLE: 1698
# PAGE TITLE: 1699
# PAGE TITLE: 1700
# PAGE TITLE: 1701
# PAGE TITLE: 1702
# PAGE TITLE: 1703
# PAGE TITLE: 1704
# PAGE TITLE: 1705
# PAGE TITLE: 1706
# PAGE TITLE: 1707
# PAGE TITLE: 1708
# PAGE TITLE: 1709
# PAGE TITLE: 1710
# PAGE TITLE: 1711
# PAGE TITLE: 1712
# PAGE TITLE: 1713
# PAGE TITLE: 1714
# PAGE TITLE: 1715
# PAGE TITLE: 1716
# PAGE TITLE: 1717
# PAGE TITLE: 1718
# PAGE TITLE: 1719
# PAGE TITLE: 1720
# PAGE TITLE: 1721
# PAGE TITLE: 1722
# PAGE TITLE: 1723
# PAGE TITLE: 1724
# PAGE TITLE: 1725
# PAGE TITLE: 1726
# PAGE TITLE: 1727
# PAGE TITLE: 1728
# PAGE TITLE: 1729
# PAGE TITLE: 1730
# PAGE TITLE: 1731
# PAGE TITLE: 1732
# PAGE TITLE: 1733
# PAGE TITLE: 1734
# PAGE TITLE: 1735
# PAGE TITLE: 1736
# PAGE TITLE: 1737
# PAGE TITLE: 1738
# PAGE TITLE: 1739
# PAGE TITLE: 1740
# PAGE TITLE: 1741
# PAGE TITLE: 1742
# PAGE TITLE: 1743
# PAGE TITLE: 1744
# PAGE TITLE: 1745
# PAGE TITLE: 1746
# PAGE TITLE: 1747
# PAGE TITLE: 1748
# PAGE TITLE: 1749
# PAGE TITLE: 1750
# PAGE TITLE: 1751
# PAGE TITLE: 1752
# PAGE TITLE: 1753
# PAGE TITLE: 1754
# PAGE TITLE: 1755
# PAGE TITLE: 1756
# PAGE TITLE: 1757
# PAGE TITLE: 1758
# PAGE TITLE: 1759
# PAGE TITLE: 1760
# PAGE TITLE: 1761
# PAGE TITLE: 1762
# PAGE TITLE: 1763
# PAGE TITLE: 1764
# PAGE TITLE: 1765
# PAGE TITLE: 1766
# PAGE TITLE: 1767
# PAGE TITLE: 1768
# PAGE TITLE: 1769
# PAGE TITLE: 1770
# PAGE TITLE: 1771
# PAGE TITLE: 1772
# PAGE TITLE: 1773
# PAGE TITLE: 1774
# PAGE TITLE: 1775
# PAGE TITLE: 1776
# PAGE TITLE: 1777
# PAGE TITLE: 1778
# PAGE TITLE: 1770-ті
# PAGE TITLE: Євро
# PAGE TITLE: 1 серпня
# PAGE TITLE: 2 серпня
# PAGE TITLE: 3 серпня
# PAGE TITLE: 4 серпня
# PAGE TITLE: 5 серпня
# PAGE TITLE: 6 серпня
# PAGE TITLE: 7 серпня
# PAGE TITLE: 8 серпня
# PAGE TITLE: 9 серпня
# PAGE TITLE: 10 серпня
# PAGE TITLE: 11 серпня
# PAGE TITLE: 12 серпня
# PAGE TITLE: 13 серпня
# PAGE TITLE: 14 серпня
# PAGE TITLE: 15 серпня
# PAGE TITLE: 16 серпня
# PAGE TITLE: 17 серпня
# PAGE TITLE: 18 серпня
# PAGE TITLE: 19 серпня
# PAGE TITLE: 20 серпня
# PAGE TITLE: 21 серпня
# PAGE TITLE: 22 серпня
# PAGE TITLE: 23 серпня
# PAGE TITLE: 24 серпня
# PAGE TITLE: 26 серпня
# PAGE TITLE: 27 серпня
# PAGE TITLE: 28 серпня
# PAGE TITLE: 29 серпня
# PAGE TITLE: 30 серпня
# PAGE TITLE: 31 серпня
# PAGE TITLE: 1 вересня
# PAGE TITLE: 2 вересня
# PAGE TITLE: 3 вересня
# PAGE TITLE: 4 вересня
# PAGE TITLE: 5 вересня
# PAGE TITLE: 6 вересня
# PAGE TITLE: 7 вересня
# PAGE TITLE: 8 вересня
# PAGE TITLE: 9 вересня
# PAGE TITLE: 10 вересня
# PAGE TITLE: 11 вересня
# PAGE TITLE: 12 вересня
# PAGE TITLE: 13 вересня
# PAGE TITLE: 14 вересня
# PAGE TITLE: 15 вересня
# PAGE TITLE: 16 вересня
# PAGE TITLE: 17 вересня
# PAGE TITLE: 18 вересня
# PAGE TITLE: 19 вересня
# PAGE TITLE: 20 вересня
# PAGE TITLE: 21 вересня
# PAGE TITLE: 22 вересня
# PAGE TITLE: 23 вересня
# PAGE TITLE: 24 вересня
# PAGE TITLE: 25 вересня
# PAGE TITLE: 26 вересня
# PAGE TITLE: 27 вересня
# PAGE TITLE: 28 вересня
# PAGE TITLE: 29 вересня
# PAGE TITLE: 30 вересня
# PAGE TITLE: 1 жовтня
# PAGE TITLE: 3 жовтня
# PAGE TITLE: 4 жовтня
# PAGE TITLE: 5 жовтня
# PAGE TITLE: 6 жовтня
# PAGE TITLE: 7 жовтня
# PAGE TITLE: 8 жовтня
# PAGE TITLE: 9 жовтня
# PAGE TITLE: 10 березня
# PAGE TITLE: 6 березня
# PAGE TITLE: 8 січня
# PAGE TITLE: 14 липня
# PAGE TITLE: 8 березня
# PAGE TITLE: 10 жовтня
# PAGE TITLE: 11 жовтня
# PAGE TITLE: 12 жовтня
# PAGE TITLE: 13 жовтня
# PAGE TITLE: 14 жовтня
# PAGE TITLE: 15 жовтня
# PAGE TITLE: 16 жовтня
# PAGE TITLE: 17 жовтня
# PAGE TITLE: 18 жовтня
# PAGE TITLE: 19 жовтня
# PAGE TITLE: 20 жовтня
# PAGE TITLE: 21 жовтня
# PAGE TITLE: 22 жовтня
# PAGE TITLE: 23 жовтня
# PAGE TITLE: 24 жовтня
# PAGE TITLE: 25 жовтня
# PAGE TITLE: 26 жовтня
# PAGE TITLE: 27 жовтня
# PAGE TITLE: 28 жовтня
# PAGE TITLE: 29 жовтня
# PAGE TITLE: 30 жовтня
# PAGE TITLE: 31 жовтня
# PAGE TITLE: 1 листопада
# PAGE TITLE: 1790-ті
# PAGE TITLE: 1780-ті
# PAGE TITLE: 1800-ті
# PAGE TITLE: 1810-ті
# PAGE TITLE: 1820-ті
# PAGE TITLE: 1830-ті
# PAGE TITLE: 1840-ві
# PAGE TITLE: 1850-ті
# PAGE TITLE: 1860-ті
# PAGE TITLE: 1870-ті
# PAGE TITLE: 1880-ті
# PAGE TITLE: 1890-ті
# PAGE TITLE: 1900-ті
# PAGE TITLE: 1910-ті
# PAGE TITLE: 1920-ті
# PAGE TITLE: 1930-ті
# PAGE TITLE: 2 листопада
# PAGE TITLE: 3 листопада
# PAGE TITLE: 4 листопада
# PAGE TITLE: 5 листопада
# PAGE TITLE: 6 листопада
# PAGE TITLE: 7 листопада
# PAGE TITLE: 8 листопада
# PAGE TITLE: 9 листопада
# PAGE TITLE: 10 листопада
# PAGE TITLE: 11 листопада
# PAGE TITLE: 12 листопада
# PAGE TITLE: 13 листопада
# PAGE TITLE: 14 листопада
# PAGE TITLE: 15 листопада
# PAGE TITLE: 16 листопада
# PAGE TITLE: 17 листопада
# PAGE TITLE: 18 листопада
# PAGE TITLE: 19 листопада
# PAGE TITLE: 20 листопада
# PAGE TITLE: 21 листопада
# PAGE TITLE: 22 листопада
# PAGE TITLE: 23 листопада
# PAGE TITLE: 24 листопада
# PAGE TITLE: 25 листопада
# PAGE TITLE: 26 листопада
# PAGE TITLE: 27 листопада
# PAGE TITLE: 28 листопада
# PAGE TITLE: 29 листопада
# PAGE TITLE: 30 листопада
# PAGE TITLE: 1 грудня
# PAGE TITLE: 2 грудня
# PAGE TITLE: 3 грудня
# PAGE TITLE: 4 грудня
# PAGE TITLE: 5 грудня
# PAGE TITLE: 6 грудня
# PAGE TITLE: 7 грудня
# PAGE TITLE: 8 грудня
# PAGE TITLE: 9 грудня
# PAGE TITLE: 2000-ні
# PAGE TITLE: 1990-ті
# PAGE TITLE: 1980-ті
# PAGE TITLE: 1970-ті
# PAGE TITLE: 1960-ті
# PAGE TITLE: 1950-ті
# PAGE TITLE: 1940-ві
# PAGE TITLE: 1760-ті
# PAGE TITLE: 1750-ті
# PAGE TITLE: 1740-ві
# PAGE TITLE: 1730-ті
# PAGE TITLE: 1720-ті
# PAGE TITLE: 1710-ті
# PAGE TITLE: 1700-ті
# PAGE TITLE: 1690-ті
# PAGE TITLE: 1680-ті
# PAGE TITLE: 1670-ті
# PAGE TITLE: 1660-ті
# PAGE TITLE: 1650-ті
# PAGE TITLE: 1640-ві
# PAGE TITLE: 1630-ті
# PAGE TITLE: 1620-ті
# PAGE TITLE: 1610-ті
# PAGE TITLE: 1600-ті
# PAGE TITLE: 10 грудня
# PAGE TITLE: 11 грудня
# PAGE TITLE: 12 грудня
# PAGE TITLE: 13 грудня
# PAGE TITLE: 14 грудня
# PAGE TITLE: 15 грудня
# PAGE TITLE: 16 грудня
# PAGE TITLE: 17 грудня
# PAGE TITLE: 18 грудня
# PAGE TITLE: 19 грудня
# PAGE TITLE: 20 грудня
# PAGE TITLE: 21 грудня
# PAGE TITLE: 22 грудня
# PAGE TITLE: 23 грудня
# PAGE TITLE: 24 грудня
# PAGE TITLE: 25 грудня
# PAGE TITLE: 26 грудня
# PAGE TITLE: 27 грудня
# PAGE TITLE: 28 грудня
# PAGE TITLE: 29 грудня
# PAGE TITLE: 30 грудня
# PAGE TITLE: 31 грудня
# PAGE TITLE: 1 січня
# PAGE TITLE: 2 січня
# PAGE TITLE: 3 січня
# PAGE TITLE: 4 січня
# PAGE TITLE: 5 січня
# PAGE TITLE: 6 січня
# PAGE TITLE: 7 січня
# PAGE TITLE: 9 січня
# PAGE TITLE: 10 січня
# PAGE TITLE: 11 січня
# PAGE TITLE: 12 січня
# PAGE TITLE: 13 січня
# PAGE TITLE: 14 січня
# PAGE TITLE: 15 січня
# PAGE TITLE: 16 січня
# PAGE TITLE: 17 січня
# PAGE TITLE: 18 січня
# PAGE TITLE: 19 січня
# PAGE TITLE: 20 січня
# PAGE TITLE: 21 січня
# PAGE TITLE: 22 січня
# PAGE TITLE: 23 січня
# PAGE TITLE: 24 січня
# PAGE TITLE: 25 січня
# PAGE TITLE: 26 січня
# PAGE TITLE: 27 січня
# PAGE TITLE: 28 січня
# PAGE TITLE: 29 січня
# PAGE TITLE: 30 січня
# PAGE TITLE: Історія
# PAGE TITLE: Історія України
# PAGE TITLE: Бандера Степан Андрійович
# PAGE TITLE: 31 січня
# PAGE TITLE: 1 лютого
# PAGE TITLE: 2 лютого
# PAGE TITLE: 3 лютого
# PAGE TITLE: 4 лютого
# PAGE TITLE: 5 лютого
# PAGE TITLE: 6 лютого
# PAGE TITLE: 7 лютого
# PAGE TITLE: 8 лютого
# PAGE TITLE: 9 лютого
# PAGE TITLE: 10 лютого
# PAGE TITLE: 11 лютого
# PAGE TITLE: 12 лютого
# PAGE TITLE: 13 лютого
# PAGE TITLE: 14 лютого
# PAGE TITLE: 15 лютого
# PAGE TITLE: 16 лютого
# PAGE TITLE: 17 лютого
# PAGE TITLE: 18 лютого
# PAGE TITLE: 19 лютого
# PAGE TITLE: 20 лютого
# PAGE TITLE: 21 лютого
# PAGE TITLE: 22 лютого
# PAGE TITLE: 23 лютого
# PAGE TITLE: 24 лютого
# PAGE TITLE: 25 лютого
# PAGE TITLE: 26 лютого
# PAGE TITLE: 27 лютого
# PAGE TITLE: 28 лютого
# PAGE TITLE: 29 лютого
# PAGE TITLE: 1 березня
# PAGE TITLE: 2 березня
# PAGE TITLE: 3 березня
# PAGE TITLE: 4 березня
# PAGE TITLE: 5 березня
# PAGE TITLE: 7 березня
# PAGE TITLE: 11 березня
# PAGE TITLE: 12 березня
# PAGE TITLE: 13 березня
# PAGE TITLE: 14 березня
# PAGE TITLE: 15 березня
# PAGE TITLE: 16 березня
# PAGE TITLE: 17 березня
# PAGE TITLE: 18 березня
# PAGE TITLE: 19 березня
# PAGE TITLE: 20 березня
# PAGE TITLE: 21 березня
# PAGE TITLE: 22 березня
# PAGE TITLE: 23 березня
# PAGE TITLE: 24 березня
# PAGE TITLE: 25 березня
# PAGE TITLE: 26 березня
# PAGE TITLE: 27 березня
# PAGE TITLE: 28 березня
# PAGE TITLE: 29 березня
# PAGE TITLE: 30 березня
# PAGE TITLE: 31 березня
# PAGE TITLE: 1 квітня
# PAGE TITLE: 2 квітня
# PAGE TITLE: 3 квітня
# PAGE TITLE: 4 квітня
# PAGE TITLE: 5 квітня
# PAGE TITLE: 6 квітня
# PAGE TITLE: 7 квітня
# PAGE TITLE: 8 квітня
# PAGE TITLE: 9 квітня
# PAGE TITLE: 10 квітня
# PAGE TITLE: 11 квітня
# PAGE TITLE: 12 квітня
# PAGE TITLE: 13 квітня
# PAGE TITLE: 14 квітня
# PAGE TITLE: 15 квітня
# PAGE TITLE: 16 квітня
# PAGE TITLE: 17 квітня
# PAGE TITLE: 18 квітня
# PAGE TITLE: 19 квітня
# PAGE TITLE: 20 квітня
# PAGE TITLE: 21 квітня
# PAGE TITLE: 22 квітня
# PAGE TITLE: 23 квітня
# PAGE TITLE: 24 квітня
# PAGE TITLE: 25 квітня
# PAGE TITLE: 26 квітня
# PAGE TITLE: 27 квітня
# PAGE TITLE: 28 квітня
# PAGE TITLE: 29 квітня
# PAGE TITLE: Список усіх дат року
# PAGE TITLE: Липень
# PAGE TITLE: Релігія
# PAGE TITLE: Іслам
# PAGE TITLE: Січень
# PAGE TITLE: Лютий
# PAGE TITLE: Березень
# PAGE TITLE: Квітень
# PAGE TITLE: Травень
# PAGE TITLE: Червень
# PAGE TITLE: Серпень
# PAGE TITLE: Вересень
# PAGE TITLE: Грудень
# PAGE TITLE: Жовтень
# PAGE TITLE: Листопад
# PAGE TITLE: 30 квітня
# PAGE TITLE: 1 травня
# PAGE TITLE: 1 червня
# PAGE TITLE: 31 травня
# PAGE TITLE: 30 червня
# PAGE TITLE: 1 липня
# PAGE TITLE: 31 липня
# PAGE TITLE: 2 травня
# PAGE TITLE: 3 травня
# PAGE TITLE: 4 травня
# PAGE TITLE: 5 травня
# PAGE TITLE: 6 травня
# PAGE TITLE: 7 травня
# PAGE TITLE: 8 травня
# PAGE TITLE: 9 травня
# PAGE TITLE: 10 травня
# PAGE TITLE: 11 травня
# PAGE TITLE: 12 травня
# PAGE TITLE: 13 травня
# PAGE TITLE: 14 травня
# PAGE TITLE: 15 травня
# PAGE TITLE: 16 травня
# PAGE TITLE: 17 травня
# PAGE TITLE: 18 травня
# PAGE TITLE: 19 травня
# PAGE TITLE: 20 травня
# PAGE TITLE: 21 травня
# PAGE TITLE: 22 травня
# PAGE TITLE: 23 травня
# PAGE TITLE: 24 травня
# PAGE TITLE: 25 травня
# PAGE TITLE: 26 травня
# PAGE TITLE: 27 травня
# PAGE TITLE: 28 травня
# PAGE TITLE: 29 травня
# PAGE TITLE: 30 травня
# PAGE TITLE: 2 червня
# PAGE TITLE: 3 червня
# PAGE TITLE: 4 червня
# PAGE TITLE: 5 червня
# PAGE TITLE: 6 червня
# PAGE TITLE: 7 червня
# PAGE TITLE: 8 червня
# PAGE TITLE: 9 червня
# PAGE TITLE: 10 червня
# PAGE TITLE: 11 червня
# PAGE TITLE: 12 червня
# PAGE TITLE: 13 червня
# PAGE TITLE: 14 червня
# PAGE TITLE: 15 червня
# PAGE TITLE: 16 червня
# PAGE TITLE: 17 червня
# PAGE TITLE: 18 червня
# PAGE TITLE: 19 червня
# PAGE TITLE: 20 червня
# PAGE TITLE: 21 червня
# PAGE TITLE: 22 червня
# PAGE TITLE: 23 червня
# PAGE TITLE: 24 червня
# PAGE TITLE: 25 червня
# PAGE TITLE: 26 червня
# PAGE TITLE: 27 червня
# PAGE TITLE: 28 червня
# PAGE TITLE: 29 червня
# PAGE TITLE: 2 липня
# PAGE TITLE: 3 липня
# PAGE TITLE: 4 липня
# PAGE TITLE: 5 липня
# PAGE TITLE: 6 липня
# PAGE TITLE: 7 липня
# PAGE TITLE: 8 липня
# PAGE TITLE: 9 липня
# PAGE TITLE: 10 липня
# PAGE TITLE: 11 липня
# PAGE TITLE: 12 липня
# PAGE TITLE: 13 липня
# PAGE TITLE: 15 липня
# PAGE TITLE: 16 липня
# PAGE TITLE: 17 липня
# PAGE TITLE: 18 липня
# PAGE TITLE: 19 липня

# %%
# create dataframe of all links from all revisions of the chosen pages
revision_links_df = pd.DataFrame(revs_links_time, columns=['parent_page', 'link', 'rvtimestamp'])
revision_links_df['link_title'] = revision_links_df['link'].apply(lambda row: multiple_replace(row))
revision_links_df['link_title'] = revision_links_df['link_title'].str.lower()

# %%
revision_links_df
# Out:
#        parent_page                         link     rvtimestamp  \
# 0        Географія              [[uk:Географя]]  20040126110432
# 1        Географія             [[af:Geografie]]  20040126110432
# 2        Географія           [[als:Geographie]]  20040126110432
# 3        Географія               [[ar:إستونيا]]  20040126110432
# 4        Географія             [[bg:География]]  20040126110432
# ...            ...                          ...             ...
# 194562        Атом         [[Референтний атом]]  20200429131823
# 194563        Атом            [[Лігатний атом]]  20200429131823
# 194564        Атом                [[Спіроатом]]  20200429131823
# 194565        Атом                [[Атом Бора]]  20200429131823
# 194566        Атом  [[Модель зануреного атома]]  20200429131823
#
#                      link_title
# 0                   uk:географя
# 1                  af:geografie
# 2                als:geographie
# 3                    ar:إستونيا
# 4                  bg:география
# ...                         ...
# 194562         референтний_атом
# 194563            лігатний_атом
# 194564                спіроатом
# 194565                атом_бора
# 194566  модель_зануреного_атома
#
# [194567 rows x 4 columns]

# %%
# get the latest revisions of pages

latest_revisions = revision_links_df.groupby(['parent_page'], sort=False)['rvtimestamp'].max()

# %%
latest_revisions

# %%
latest_revisions_df = latest_revisions.to_frame()
latest_revisions_df.to_csv('../working_files/'+'latest_revisions_df.csv', sep='^')

# %%
# !Run Once
# creates a file of links from all revisions of the chosen pages
revision_links_df.to_pickle('/media/andrii/earth/Katia/CS/!redlinks_project/red-links-v2.0/working_files/'+'revision_links_1000pages.pkl')

# %%
revision_links_df = pd.read_pickle('/media/andrii/earth/Katia/CS/!redlinks_project/red-links-v2.0/working_files/'+'revision_links_1000pages.pkl')

# %%
# get links from the revisions of a certain time period
revision_links_df_after2010 = revision_links_df.drop(revision_links_df[revision_links_df.rvtimestamp.map(lambda x: int(x.strftime("%Y")) < 2010)].index)

# %%
# create a table of links with their status (red/blue/check)

page_creation_df['ref_title'] = page_creation_df['ref_title'].str.lower()
page_creation_df['main_page_title'] = page_creation_df['main_page_title'].str.lower()

link_df = revision_links_df_after2010.merge(page_creation_df, left_on='link_title', right_on='ref_title', how='left')

del link_df['ref_title']

# clean noise links
noise_langlinks = ('af:', 'als:', 'ar', 'bg:', 'bs:', 'ca:', 'cs:', 'da:', 'de:', 'el:', 'en:', 'es:', 'et:',
                   'eu:', 'fi:', 'fr:', 'ga:', 'hi:', 'hr:', 'hu:', 'ia:', 'is:', 'it:', 'ja:', 'ko:', 'la:',
                   'lt:', 'nl:', 'no:', 'oc:', 'pl:', 'pt:', 'ro:', 'ru:', 'sk:', 'sl:', 'sq:', 'sr:', 'sv:',
                   'sw:', 'tr:', 'uk:', 'zh:', 'co:', 'cy:', 'eo:', 'fy:', 'gl:', 'he:', 'id:', 'ks:', 'lv:',
                   'ms:', 'nds:', 'simple:', 'th:', 'category:', 'ast:', 'az:', 'csb:', 'ie:', 'lb:', 'te:',
                   'tl:', 'ur:', 'vi:', 'vo:', 'zh-cn:', 'image:', 'be:', 'bn:', 'br:', 'io:', 'ka:', 'mg:',
                   'mk:', 'mt:', 'rm:', 'scn:', 'ab:', 'fo:', 'fur:', 'li:', 'ab:', 'an:', 'ba:', 'ky:', 'nn:',
                   'os:', 'kv:', 'sc:', 'ceb:', 'lad:', 'mh:', 'gu:', 'ta:', 'to:', 'tk:', 'зображення:', 'av:',
                   'bat-smg:', 'bm:', 'cv:', 'ku:', 'kw:', 'lmo:', 'nrm:', 'ps:', 'rmy:', 'sh:', 'tg:', 'ug:',
                   'uz:', 'vec:', 'zh-yue:', 'ilo:', 'bar:', 'iu:', 'nov:', 'wa:', 'qu:', 'wa:', 'my:', 'frp:',
                   'hsb:', 'nah:', 'yi:', 'ht:', 'mr:', 'ng:', 'sco:', 'su:', 'be-x-old:', 'ne:', 'km:', 'mn:',
                   'sm:', 'fa:', 'lij:', 'map-bms:', 'ml:', 'ru-sib:', 'jv:', 'wo:', 'tpi:', 'as:', 'tpi:', 'lo:',
                   'bh:', 'war:', 'mzn:', 'pms:', 'stq:', 'szl:', 'ay:', 'si:', 'fiu-vro:', 'ln:', 'bcl:', 'ln:',
                   'dv:', 'gn:', 'pam:', 'so:', 'zea:', 'ext:', 'gan:', 'hy:', 'sah:', 'ak:', 'kab:', 'nds-nl:',
                   'mdf:', 'ts:', 'gv:', 'pnt:', 'kk:', 'zh-min-nan:', 'jbo:', 'kn:', 'kl:', 'mwl:', 'hif:', 'mhr:',
                   'yo:', 'new:', 'pcd:', 'tt:', 'krc:', 'am:', 'frr:', 'ig:', 'pnb:', 'bo:', 'bi:', 'ss:', 'rue:',
                   'kbd:', 'zh-classical:', 'sn:', 'sa:', 'roa-tara:', 'gd:', 'cbk-zam:', 'lez:', 'nso:', 'ckb:',
                   'vep:', 'pa:', 'file:', 'kaa:', 'pfl:', 'haw:', 'pih:', 'mo:', 'ee:', 'xh:', 'srn:', 'wuu:',
                   'ksh:', 'ki:', 'szl:', 'crh:', 'zh-tw:', 'dsb:', 'lg:', 'koi:', 'xal:', 'jp:', 'pih:', 'hak:',
                   ':категорія:', 'cu:', ':ru:', 'ff:', 'wikipedia:en:', 'bug:', 'xmf:', 'ce:', 'diq:', 'vls:',
                   'bsd', 'myv:', 'bjn:', 'or:', 'ti:', 'cdo:', 'mi:', 'pap:', 'se:', 'історія_науки#',
                   'planetmath:', 'pi:', 'ty:', 'tet:', 'bpy:', 'nap:', 'gag:', 'ang:', 'udm:',
                   'zu:', 'rw:', 'lbe:', 'za:', 'ha:', 'ch:', 'nb:', 'min:', 'bxr:', 'ace:', 'pag:',
                   'вікіпедія:', 'спеціальна:', 'користувач:', 'ik:', 'roa-rup:', 'ltg:', 'tlh:', 'got:', 'rn:',
                   'tokipona:', 'minnan:', 'довідка:', 'nv:', 'eml:', 'na:', 'kg:', 'sd:', 'wikipedia:', 'chr:',
                   'pdc:', 'fj:', 'портал:')

link_df_clean = link_df.drop(link_df[link_df.link_title.astype(str).str.startswith(noise_langlinks)].index)

link_status_df = link_df_clean.drop(link_df_clean[link_df_clean.link_title.map(lambda x: '#' in str(x))].index)

link_status_df.min_pagecreation_timestamp =\
link_status_df.min_pagecreation_timestamp.apply(lambda x: Timestamp(np.int64(x)) if (pd.notnull(x)) else x)

link_status_df['link_status'] = link_status_df.apply(lambda x: link_status(x['rvtimestamp'], x['min_pagecreation_timestamp']), axis=1)

# %%
# write a table with link status to file

link_status_df.to_pickle('/media/andrii/earth/Katia/!redlinks_project/'+'link_status_1000pages_after2010.pkl')
#unpickled_df = pd.read_pickle("./dummy.pkl")

# %%
# get a table only with red links and write it to file
df_red = link_status_df.loc[link_status_df['link_status'] == 'red link']

df_red['rvtimestamp'] = df_red.rvtimestamp.apply(lambda x: datetime.fromtimestamp(x).date().replace(day=1))

df_red_less = df_red[['parent_page', 'rvtimestamp', 'link_title', 'link_status']]


df_red_less_unique = df_red_less.drop_duplicates()

df_red_less_unique.to_csv('../'+'df_red_less_unique.csv', index=False, sep='^')
# Out:
# /home/andrii/virtenvs/tb/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# count number of unique red links for a revision of a page

df_red_less_unique_time = df_red_less_unique_time.drop(df_red_less_unique_time[df_red_less_unique_time.rvtimestamp.map(lambda x: int(x.split('-')[0]) < 2010)].index)

df_red_less_unique_time = df_red_less_unique.groupby(['parent_page', 'rvtimestamp']).size().reset_index(name='counts')

df_red_less_unique_time.to_csv('../'+'df_red_less_unique_time.csv', index=False, sep='^')
